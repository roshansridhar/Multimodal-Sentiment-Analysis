# %% [markdown]
# ## Text analysis on the MOUD dataset

# %% [markdown]
# This notebook contains a model to evaluate text data from the MOUD dataset using bag of words and TF-IDF.

# %%
# The path of the train and test transcriptions
# The data is seperated in an 80-20 ratio and the test directory is untouched. 
train_path = r"C:\Users\Roshan Sridhar\Google Drive\Documents\NYU\GILAB\MMML\Datasets\MOUD\VideoReviews\transcriptions\train\*.csv"
test_path = r"C:\Users\Roshan Sridhar\Google Drive\Documents\NYU\GILAB\MMML\Datasets\MOUD\VideoReviews\transcriptions\test\*.csv"

# %%
import glob
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.DataFrame()
for f in glob.glob(train_path):
    df = df.append(pd.read_csv(f,sep=';'),ignore_index=True)
# df = pd.concat((pd.read_csv(f,sep=';'),ignore_index=True for f in glob.glob(path)))
df
# Out:
#      #endtime  #starttime                                             Speech  \
# 0       3.642       0.000                                                NaN
# 1       9.552       3.642                                                NaN
# 2      14.197       9.552                                                NaN
# 3      20.545      14.197                                                NaN
# 4      23.275      20.545                                                NaN
# 5      27.533      23.275                                                NaN
# 6      31.004      27.533                                                NaN
# 7      32.600      31.004                                                NaN
# 8      34.133      32.600                                                NaN
# 9       6.643       0.000                                                NaN
# 10     17.290       6.643                                                NaN
# 11     23.475      17.290                                                NaN
# 12     26.714      23.475                                                NaN
# 13     33.367      26.714                                                NaN
# 14      4.956       0.000                                                NaN
# 15      7.954       4.956                                                NaN
# 16     13.305       7.954                                                NaN
# 17     19.397      13.305                                                NaN
# 18     34.133      19.397                                                NaN
# 19      3.540       0.000          mm: y- hara su efecto aunque: no lo notes
# 20     13.890       3.540  pero lo que no me gusta de este: de este produ...
# 21     21.122      13.890  En vez de ser un spray que se difumine y te ca...
# 22     26.010      21.122  Asi que: sera buen producto pero yo no: // eh:...
# 23     29.820      26.010  Es que es mm: no me lo puedo echar bien por el...
# 24     31.765      29.820                 asi que, // no lo recomiendo si s-
# 25      2.980       0.000                                                NaN
# 26      7.020       2.980                                                NaN
# 27     14.790       7.020                                                NaN
# 28     18.470      14.790                                                NaN
# 29     23.506      18.470                                                NaN
# ..        ...         ...                                                ...
# 364     7.740       0.000  del el nerd, el timido, el imbecil, que quiere...
# 365    14.107       7.740  Y pus que hacen una fiesta, y en algun momento...
# 366    19.205      14.107  Eh se empieza a poner loca, y bueno todo sale ...
# 367    28.302      19.205  Porque la mayoria de la banda que la ha visto ...
# 368    33.599      28.302  Es lo unico que vas a ir a ver, a ver chavillo...
# 369     7.390       0.000  Por que de hecho se c- se critica muc:ho en es...
# 370    19.010       7.390  o sea, basicamente es una vision bastante pigg...
# 371    22.722      19.020  La verdad, es que yo no creo que sean los adol...
# 372    26.418      22.722      Yo tengo mucha fe en ellos y este y bueno. //
# 373    32.600      26.418  Si vas a ir a verla, tienes que ir con la idea...
# 374     3.520       0.000          Una semana en leerlo. // ¿Ustedes creen?
# 375     6.233       3.530   Bueno, no una semana exactamente, pero casi. ...
# 376    11.044       6.233  Y normalmente un libro de trescientas y algo d...
# 377    16.881      11.044  Asi de mucho de tarde porque no me gusto. No m...
# 378    21.634      16.881  Obviamente, no quiero ofender a las personas q...
# 379    23.850      21.634   Pero definitivamente, este libro no fue para mi.
# 380    32.926      23.850  No puedo creer que haya habido un momento en e...
# 381    10.974       0.000  Lo que yo pienso. Lo que yo opino es // que to...
# 382    20.925      10.974  Lo que: nos hace sentir tambien identificados ...
# 383    33.227      20.925  Este. // Son sus libros muy, muy originales, /...
# 384     4.461       0.000  Creo que es una historia que engancha / muchis...
# 385    10.882       4.461  em: hay momentos de risa, hay momentos de llor...
# 386    13.400      10.882   El principio es un poco lioso, pero te engacha.
# 387    21.702      13.410  Os lo digo que / em: / la historia, el trama q...
# 388    26.290      21.702  Y: bueno voy a dejarlo aqui abajo, porque me e...
# 389    31.230      26.290  Y: bueno, de momento, es el que me estoy leyen...
# 390     8.048       0.000  eh:m A mi Crepusculo: / no se si lo lei en el ...
# 391    15.306       8.048  Se que hay mucha juventud que lo ha leido, cad...
# 392    28.483      15.306  Y: yo tengo una batalla: un poco: / con la gen...
# 393    31.880      28.483  Y para mi no es asi, o sea, vale, hay mucho de de
#
#      sentimentAnnotation  sentimentAnnotations  sentimentannotations speech  \
# 0                    NaN                  -1.0                   NaN    NaN
# 1                    NaN                  -1.0                   NaN    NaN
# 2                    NaN                  -1.0                   NaN    NaN
# 3                    NaN                  -1.0                   NaN    NaN
# 4                    NaN                   1.0                   NaN    NaN
# 5                    NaN                   1.0                   NaN    NaN
# 6                    NaN                   1.0                   NaN    NaN
# 7                    NaN                   1.0                   NaN    NaN
# 8                    NaN                  -1.0                   NaN    NaN
# 9                    NaN                   1.0                   NaN    NaN
# 10                   NaN                   1.0                   NaN    NaN
# 11                   NaN                   1.0                   NaN    NaN
# 12                   NaN                   1.0                   NaN    NaN
# 13                   NaN                   1.0                   NaN    NaN
# 14                   NaN                   1.0                   NaN    NaN
# 15                   NaN                   1.0                   NaN    NaN
# 16                   NaN                   1.0                   NaN    NaN
# 17                   NaN                   1.0                   NaN    NaN
# 18                   NaN                   1.0                   NaN    NaN
# 19                   NaN                   1.0                   NaN    NaN
# 20                   NaN                  -1.0                   NaN    NaN
# 21                   NaN                  -1.0                   NaN    NaN
# 22                   NaN                  -1.0                   NaN    NaN
# 23                   NaN                  -1.0                   NaN    NaN
# 24                   NaN                  -1.0                   NaN    NaN
# 25                   NaN                  -1.0                   NaN    NaN
# 26                   NaN                   1.0                   NaN    NaN
# 27                   NaN                  -1.0                   NaN    NaN
# 28                   NaN                  -1.0                   NaN    NaN
# 29                   NaN                  -1.0                   NaN    NaN
# ..                   ...                   ...                   ...    ...
# 364                  NaN                  -1.0                   NaN    NaN
# 365                  NaN                  -1.0                   NaN    NaN
# 366                  NaN                  -1.0                   NaN    NaN
# 367                  NaN                  -1.0                   NaN    NaN
# 368                  NaN                  -1.0                   NaN    NaN
# 369                  NaN                  -1.0                   NaN    NaN
# 370                  NaN                  -1.0                   NaN    NaN
# 371                  NaN                   1.0                   NaN    NaN
# 372                  NaN                   1.0                   NaN    NaN
# 373                  NaN                  -1.0                   NaN    NaN
# 374                  NaN                  -1.0                   NaN    NaN
# 375                  NaN                  -1.0                   NaN    NaN
# 376                  NaN                   1.0                   NaN    NaN
# 377                  NaN                  -1.0                   NaN    NaN
# 378                  NaN                  -1.0                   NaN    NaN
# 379                  NaN                  -1.0                   NaN    NaN
# 380                  NaN                  -1.0                   NaN    NaN
# 381                  NaN                   1.0                   NaN    NaN
# 382                  NaN                   1.0                   NaN    NaN
# 383                  NaN                   1.0                   NaN    NaN
# 384                  NaN                   1.0                   NaN    NaN
# 385                  NaN                   1.0                   NaN    NaN
# 386                  NaN                   1.0                   NaN    NaN
# 387                  NaN                   1.0                   NaN    NaN
# 388                  NaN                  -1.0                   NaN    NaN
# 389                  NaN                   1.0                   NaN    NaN
# 390                  NaN                   1.0                   NaN    NaN
# 391                  NaN                   1.0                   NaN    NaN
# 392                  NaN                  -1.0                   NaN    NaN
# 393                  NaN                  -1.0                   NaN    NaN
#
#                                          transcription
# 0    yo habia visto resenas que decian que picaba c...
# 1    y la verdad es que si la use una vez y t- y te...
# 2    y dije no: puede ser posible tanto la deseaba ...
# 3    esta tambien tira un poquito de pelo pero haga...
# 4    pero igual con las lavadas se ha dejado de tir...
# 5    em: se lavan super facil, se secan rapido se s...
# 6    y: bueno con las lavadas ya no: raspa tanto ya...
# 7                                   ya esta soportable
# 8                               // pues si: pica un p-
# 9    Y lo que me encanto de esta pelicula es que es...
# 10   luego pues cada tenemos esta historia que esta...
# 11   esta su:per interesante, porque ya: la neta to...
# 12   Y: despues de ver la pelicula piensas mas que ...
# 13   entonces, como agarro a estos tres personajes ...
# 14   Este resumen no les- no le hace justicia, esta...
# 15   es uno de los mejores libros que he leido en m...
# 16   y como les habia dicho en mi video anterior. S...
# 17   No porque se parezca la historia sino porque: ...
# 18   lo que mas me gusto de este libro es que ya cu...
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25              // No recomiendo la crema americana.
# 26   Todo el mundo dice que huele genial, // que: d...
# 27   Pero este producto eh: deja el pelo seco, es q...
# 28   Pone suavizante con el doble de potencia, pero...
# 29   // es un producto que no merece la pena, deja ...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
# 369                                                NaN
# 370                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392                                                NaN
# 393                                                NaN
#
# [394 rows x 8 columns]

# %% [markdown]
# As shown, there are multiple speech and annotation columns. This requires data consolidation and managing missing values.

# %%
# funcion to append all utterances to dataframe
def create_data_df(df_name,data_path):
    
    # Creating dataframe of entire transcriptions
    for f in glob.glob(data_path):
        df_name = df_name.append(pd.read_csv(f,sep=';'),ignore_index=True)
    
    # combine multiple speech, annotation columns to one and drop rest of columns
    if 'Speech' not in df_name.columns:
        df_name['Speech'] = ''    
    if 'speech' in df_name.columns:
        df_name['Speech'] = df_name[['Speech','speech']].fillna('').sum(axis=1)   
    if 'transcription' in df_name.columns:
        df_name['Speech'] = df_name[['Speech','transcription']].fillna('').sum(axis=1)
    
    if 'sentimentAnnotation' not in df_name.columns:
        df_name['sentimentAnnotation'] = 0    
    if 'sentimentAnnotations' in df_name.columns:
        df_name['sentimentAnnotation'] = df_name[['sentimentAnnotation','sentimentAnnotations']].fillna(0).sum(axis=1)
    if 'sentimentannotations' in df_name.columns:
        df_name['sentimentAnnotation'] = df_name[['sentimentAnnotation','sentimentannotations']].fillna(0).sum(axis=1)
    
    # Remove neutral annotations
    df_name = df_name.query('sentimentAnnotation != 0')
    
    df_name = df_name[['Speech','sentimentAnnotation']].reset_index(drop=True)  
    return df_name

# %% [markdown]
# Cleaned transcriptions

# %%
df = pd.DataFrame()
df_t = pd.DataFrame()
df = create_data_df(df,train_path)
df_t = create_data_df(df_t,test_path)
df_t
# Out:
#                                                Speech  sentimentAnnotation
# 0                        pero de verdad lo recomiendo                    1
# 1    porque es que: eh: tiene de todo o sea no es el:                    1
# 2      no he leido nunca ningun libro de esos zombies                   -1
# 3   pero de peliculas y tal a mi que tampoco me su...                    1
# 4   que la verdad no me gusta, pero no estamos hab...                   -1
# 5   me ha: gustado mucho porque es: Diario de un z...                    1
# 6   una persona que: se ha convertido en zombie pe...                    1
# 7   y bueno y: tiene muchos momentos de risa de ca...                    1
# 8   momentos tristes de tension con unas- describe...                    1
# 9   Te queda como el pelo estropajoso, je te lo la...                   -1
# 10  pues no se que efecto hace la verdad, // no se...                   -1
# 11  Y arenoso, como recien salido del mar, no, no ...                   -1
# 12  pues yo pense que esta crema lo que hacia era ...                   -1
# 13  Pero no, a mi me queda el pelo como estropajos...                   -1
# 14   Como justamente esto, explotacion de franquicias                   -1
# 15  y visualmente, ya n- a pesar de que estan muy ...                   -1
# 16  Eso es lo que creo que habria que criticarle a...                   -1
# 17  creo que se estan conformando con: entrenter a...                   -1
# 18  y con que sus peliculas sean un exito en taqui...                   -1
# 19  Pero creo que en busqueda de, de creo que en e...                   -1
# 20  Las cosas que no me gustaron es que siento que...                   -1
# 21  O sea, como que de repente pasan muchos capitu...                   -1
# 22  y la situacion que estan viviendo ellas no es ...                   -1
# 23  Y eso me molesta me m- siento que los libros s...                   -1
# 24  Otra cosa que no me gusta es que de repente, /...                   -1
# 25  Mis libros favoritos, es mi trilogia favorita ...                    1
# 26             Creo que todo el mundo deberia leerlo.                    1
# 27  Creo que la inmensa mayoria de la gente que lo...                    1
# 28  Yo no conozco a nadie que lo haya leido y me h...                    1
# 29                Asi de simple, no conozco a nadie.                     1
# ..                                                ...                  ...
# 65  Eh, siempre tiene las mejores palabras para ex...                    1
# 66  Laura Gallego para mi, es eh es una idola, y y...                    1
# 67         Todos los libros de ella me han encantado.                    1
# 68  em, no se. Para mi, Laura Gallego es ir es ir ...                    1
# 69  Y ahora mismo, mirad por donde voy. Me queda s...                    1
# 70                     Y la verdad es que me encanta.                    1
# 71  Este, no se siente nada grasoso; ni: siento qu...                    1
# 72  Y: la verdad es que me gusta mucho, y siempre ...                    1
# 73  Pues esta ves que fui a Mexico, me compre dos ...                   -1
# 74  Y: este me costo noventa y cinco pesos en una ...                    1
# 75                 Otras de las cosas que compre fue-                    1
# 76  La verdad, / me encanto. Me sorprendio mucho e...                    1
# 77  No punfue- no pense que me fuera a gustar tanto.                    -1
# 78  Me gusto muchisimo. Y un: toque que me encanto...                    1
# 79  No se. Me encanto ese detalle.  Me encanto el ...                    1
# 80  Y si les gustan las historia de una sociedad /...                    1
# 81                   A mi me ha encantado, la verdad.                    1
# 82  Y: decir que los personajes tienen unas cosas ...                    1
# 83                                 Son muy naturales.                    1
# 84  Y ese es lo que al final al cabo todos deberia...                    1
# 85  Viendo como interactuan entre ellos, como / co...                    1
# 86                       Y es es un libro fantastico.                    1
# 87  Ya digo, no es un libro: realista, a pesar de ...                    1
# 88                          Y aun asi // es fabuloso.                    1
# 89                                   Esta padrisimo.                     1
# 90  Ya en otros li- en otros videos ya les he dich...                    1
# 91  Si tienen curiosidad, o si les ha llamado la a...                    1
# 92  O sea, / yo la primera vez que los vi no se me...                   -1
# 93  Y aqui estoy, cinco libros despues, siendo sup...                    1
# 94  A veces, no se, o sea leyendo este libro senti...                    1
#
# [95 rows x 2 columns]

# %% [markdown]
# #### ALTERNATE Converting video to test data

# %% [markdown]
# This alternate section is for feeding a video to a trained model and perform sentiment analysis on it. A video is fed to the path in the next code section and IBM Bluemix Speech to Text is used to obtain the transcriptions.
#
# Else skip to Data processing.

# %%
# Convert video to audio, insert path
# vpath = r"C:\Datasets\MOUD\VideoReviews\178_makeup.mp4"

# Using a wav from video-audio-converter as video file did not operate as intended 
apath = r"C:\Users\Roshan Sridhar\Google Drive\Documents\NYU\GILAB\MMML\Python\MOUD\Text_Video\178_makeup.wav"

# %%
# Using IBM Bluemix to convert Speech to Text 
import json
from os.path import join, dirname
from watson_developer_cloud import SpeechToTextV1

speech_to_text = SpeechToTextV1(
    username='d6663de6-8281-4351-a718-4405ea503686',
    password='TAGa0GJdBrS8',
    x_watson_learning_opt_out=False
)

with open(apath,
          'rb') as audio_file:
    trn = speech_to_text.recognize(
        audio_file, content_type='audio/wav', timestamps=False, model='es-ES_BroadbandModel',
        word_confidence=False)

# %%
df_t = pd.DataFrame(columns = ['Speech','sentimentAnnotation'])
for i in range(len(trn['results'])):
    df_t.loc[len(df_t)]=[trn['results'][i]['alternatives'][0]['transcript'],'Unknown']
print("Converted Speech to Text utterances in the Speech column")
df_t

# %% [markdown]
# ### Data cleaning and text preprocessing

# %%
# from https://www.kaggle.com/c/word2vec-nlp-tutorial/
import re
from bs4 import BeautifulSoup
import nltk

# execute the following commented step to install the data packages if you don't already have it  
# nltk.download()

from nltk.corpus import stopwords

# resuable function to convert raw speech to preprocessed
def utterance_to_words(raw_utterance):
    # 1. Removing HTML elements from text
    utterance_text = BeautifulSoup(raw_utterance, "lxml").get_text()
    # 2. Keeping only letters
    letters_only = re.sub("[^a-zA-Z]", " ", utterance_text) 
    # 3. Converting to lower case and splitting into individual words
    lowercase_words = letters_only.lower().split()
    # 4. converting the stop words to a set to help faster execution
    spanish_stops = set(stopwords.words("spanish"))
    # 5. Removing stop words from the text
    meaningful_words = [w for w in lowercase_words if not w in spanish_stops]
    # 6. Join the words back into one string separated by space, and return the result.
    return( " ".join( meaningful_words ))
    
# applying the function to the speech columns
df['Speech'] = df['Speech'].apply(lambda x: utterance_to_words(x))
df_t['Speech'] = df_t['Speech'].apply(lambda x: utterance_to_words(x))
df
# Out:
#                                                 Speech  sentimentAnnotation
# 0             habia visto resenas decian picaba usabas                 -1.0
# 1           verdad si use vez t arde asi usas arde ojo                 -1.0
# 2    dije puede ser posible deseaba arde voy poder ...                 -1.0
# 3    tambien tira poquito pelo hagan cuenta quebra ...                 -1.0
# 4                           igual lavadas dejado tirar                  1.0
# 5       em lavan super facil secan rapido secan rapido                  1.0
# 6                            bueno lavadas raspa raspa                  1.0
# 7                                           soportable                  1.0
# 8                                       pues si pica p                 -1.0
# 9    encanto pelicula recurso utilizan m uy bien c ...                  1.0
# 10   luego pues cada historia interesante verdad pr...                  1.0
# 11   per interesante neta siempre queremos tener su...                  1.0
# 12   despues ver pelicula piensas mas vas tener sup...                  1.0
# 13   entonces agarro tres personajes ven tan comune...                  1.0
# 14              resumen hace justicia padri simo libro                  1.0
# 15        mejores libros leido muchisimo tiempo verdad                  1.0
# 16   habia dicho video anterior si ustedes gusta ha...                  1.0
# 17   parezca historia sino tratan asi tem temas mag...                  1.0
# 18   mas gusto libro llegas final cambian pasa vera...                  1.0
# 19                         mm hara efecto aunque notes                  1.0
# 20   gusta producto das ver si puedo hacer sale muc...                 -1.0
# 21   vez ser spray difumine caiga mas producto pelo...                 -1.0
# 22                     asi sera buen producto eh gusta                 -1.0
# 23   mm puedo echar bien pelo echarme muchisimo pro...                 -1.0
# 24                                 asi recomiendo si s                 -1.0
# 25                          recomiendo crema americana                 -1.0
# 26              mundo dice huele genial deja pelo bien                  1.0
# 27   producto eh deja pelo seco eh eches mm aunque ...                 -1.0
# 28   pone suavizante doble potencia deja pelo sequi...                 -1.0
# 29       producto merece pena deja siquiera huele bien                 -1.0
# ..                                                 ...                  ...
# 325  nerd timido imbecil quieren ser famosos quiere...                 -1.0
# 326  pus hacen fiesta algun momento fiesta pierde c...                 -1.0
# 327  eh empieza poner loca bueno sale control bueno...                 -1.0
# 328  mayoria banda visto dice pues si vas ver histo...                 -1.0
# 329  unico vas ir ver ver chavillos tomar chavas ha...                 -1.0
# 330  hecho c critica muc ho pelicula hecho actrices...                 -1.0
# 331  basicamente vision bastante pigglish segun vis...                 -1.0
# 332          verdad creo adolescentes asi menos espero                  1.0
# 333                                     mucha fe bueno                  1.0
# 334  si vas ir verla ir idea vas ir ver pelicula hi...                 -1.0
# 335                        semana leerlo ustedes creen                 -1.0
# 336                 bueno semana exactamente casi dias                 -1.0
# 337  normalmente libro trescientas paginas acabo do...                  1.0
# 338       asi tarde gusto gusto habia na libro gustara                 -1.0
# 339  obviamente quiero ofender personas gustado lib...                 -1.0
# 340                              definitivamente libro                 -1.0
# 341  puedo creer momento pensado libros podian ser ...                 -1.0
# 342  pienso opino toma magia fantasia realidad exis...                  1.0
# 343  hace sentir tambien identificados personajes p...                  1.0
# 344  libros originales toque comedia tambien divert...                  1.0
# 345          creo historia engancha muchisimo preciosa                  1.0
# 346  em momentos risa momentos llorar momentos enti...                  1.0
# 347                            principio lioso engacha                  1.0
# 348  digo em historia trama maravilloso recomiendo ...                  1.0
# 349         bueno voy dejarlo aqui abajo cansando mano                 -1.0
# 350       bueno momento leyendo ahora empezare despues                  1.0
# 351     eh m crepusculo si lei momento ideoneo fascino                  1.0
# 352  mucha juventud leido cada vez loca protagonist...                  1.0
# 353  batalla gente mas mayor dado cuenta categoriza...                 -1.0
# 354                                           asi vale                 -1.0
#
# [355 rows x 2 columns]

# %% [markdown]
# ### Machine learning

# %%
X_trn, y_trn = df[['Speech']],df[['sentimentAnnotation']]

# countVectorizer initialization
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             lowercase = True,    \
                             max_features = 5000) 

# create bag of words vector for the training set using countVectorizer
train_data_features = vectorizer.fit_transform(X_trn['Speech'].values)

# tf-idf transformer initialization
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()

# create tfidf transformed vector  for the training set using tf-idf transformer
X_train_tfidf = tfidf_transformer.fit_transform(train_data_features)

# %%
X_tst, y_tst = df_t[['Speech']],df_t[['sentimentAnnotation']]

# transformation of test data
test_data_features = vectorizer.transform(X_tst['Speech'].values)
X_test_tfidf = tfidf_transformer.transform(test_data_features)

# %%
# SVM model creation and fitting train vector to annotations

from sklearn import svm
model_tf = svm.SVC(kernel='linear', C=1, gamma=1).fit(X_train_tfidf,y_trn['sentimentAnnotation'].values)

# generate predictions
predicted_tf = model_tf.predict(X_test_tfidf)

# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_tst['sentimentAnnotation'].values, predicted_tf))

#create df to show results
disp = X_tst.join(y_tst).reset_index(drop=True).join(pd.DataFrame(predicted_tf,columns=['Prediction']))
disp = disp.join(pd.DataFrame(disp['sentimentAnnotation']==disp['Prediction'],columns=['Right/Wrong']))

scores = model_tf.score(X_test_tfidf,y_tst['sentimentAnnotation'].values)
print("Accuracy: %0.2f (+/- %0.2f)\n" % (scores.mean(), scores.std() * 2))
print("Mean sentiment: {!r}.".format('Positive' if disp['sentimentAnnotation'].mean()>=0 else 'Negative'))
                            
print("Predicted mean sentiment: {!r}.".format('Positive' if disp['Prediction'].mean()>=0 else 'Negative'))
disp
# Out:
#              precision    recall  f1-score   support
#
#          -1       0.62      0.90      0.73        41
#           1       0.89      0.57      0.70        54
#
# avg / total       0.77      0.72      0.71        95
#
# Accuracy: 0.72 (+/- 0.00)
#
# Mean sentiment: 'Positive'.
# Predicted mean sentiment: 'Negative'.
#                                                Speech  sentimentAnnotation  \
# 0                                   verdad recomiendo                    1
# 1                                                  eh                    1
# 2                    leido nunca ningun libro zombies                   -1
# 3   peliculas tal tampoco suelen hacer mucha graci...                    1
# 4                               verdad gusta hablando                   -1
# 5               gustado diario zombie cuenta perso na                    1
# 6   persona convertido zombie realmente piensa per...                    1
# 7                       bueno momentos risa cachondeo                    1
# 8   momentos tristes tension unas describe cosas b...                    1
# 9   queda pelo estropajoso je lavas desenreda das ...                   -1
# 10        pues efecto hace verdad efecto quiera hacer                   -1
# 11  arenoso recien salido mar luego salido mar pei...                   -1
# 12  pues pense crema hacia hidratarme tener olor c...                   -1
# 13  queda pelo estropajoso luego dificilisimo pued...                   -1
# 14                 justamente explotacion franquicias                   -1
# 15  visualmente n pesar estan bien hechas demasiad...                   -1
# 16                  creo habria criticarle dreamworks                   -1
# 17           creo estan conformando entrenter publico                   -1
# 18  peliculas exito taquilla seguir abultando cuen...                   -1
# 19  creo busqueda creo cuanto terminos busqueda eh...                   -1
# 20  cosas gustaron siento autora digo repente da m...                   -1
# 21                    repente pasan capitulos pasando                   -1
# 22   situacion estan viviendo tampoco tan entretenida                   -1
# 23  molesta m siento libros pudieron haber ido mas...                   -1
# 24  cosa gusta repente va narracion luego empiezan...                   -1
# 25  libros favoritos trilogia favorita trilogia fa...                    1
# 26                          creo mundo deberia leerlo                    1
# 27        creo inmensa mayoria gente leido encantando                    1
# 28                   conozco nadie leido dicho mierda                    1
# 29                           asi simple conozco nadie                    1
# ..                                                ...                  ...
# 65             eh siempre mejores palabras explicarlo                    1
# 66  laura gallego eh idola adoro toda alma siempre...                    1
# 67                                   libros encantado                    1
# 68                      em laura gallego ir ir seguro                    1
# 69          ahora mismo mirad voy queda solo terminar                    1
# 70                                     verdad encanta                    1
# 71            grasoso siento deje pelo asi seboso dia                    1
# 72  verdad gusta siempre siempre voy mencione trat...                    1
# 73   pues ves mexico compre dos mas traia presupuesto                   -1
# 74  costo noventa cinco pesos farmacia pueden enco...                    1
# 75                                       cosas compre                    1
# 76                    verdad encanto sorprendio libro                    1
# 77                                punfue pense gustar                   -1
# 78  gusto muchisimo toque encanto dio autora inici...                    1
# 79                      encanto detalle encanto libro                    1
# 80  si gustan historia sociedad eh oprimida hunger...                    1
# 81                                   encantado verdad                    1
# 82             decir personajes unas cosas divertidas                    1
# 83                                          naturales                    1
# 84  final cabo deberian ser personajes tan creible...                    1
# 85  viendo interactuan graduan hablan pareja encue...                    1
# 86                                   libro fantastico                    1
# 87  digo libro realista pesar personajes libro fan...                    1
# 88                                   aun asi fabuloso                    1
# 89                                          padrisimo                    1
# 90    li videos dicho tratan libros cazadores sombras                    1
# 91  si curiosidad si llamado atencion dicen leere ...                    1
# 92                    primera vez vi hacia tan padres                   -1
# 93  aqui cinco libros despues siendo super fan jur...                    1
# 94  veces leyendo libro senti cassandra claire si ...                    1
#
#     Prediction  Right/Wrong
# 0          1.0         True
# 1         -1.0        False
# 2          1.0        False
# 3         -1.0        False
# 4          1.0        False
# 5         -1.0        False
# 6         -1.0        False
# 7          1.0         True
# 8          1.0         True
# 9         -1.0         True
# 10        -1.0         True
# 11        -1.0         True
# 12        -1.0         True
# 13        -1.0         True
# 14        -1.0         True
# 15        -1.0         True
# 16        -1.0         True
# 17        -1.0         True
# 18         1.0        False
# 19        -1.0         True
# 20        -1.0         True
# 21        -1.0         True
# 22        -1.0         True
# 23        -1.0         True
# 24        -1.0         True
# 25         1.0         True
# 26        -1.0        False
# 27         1.0         True
# 28         1.0         True
# 29        -1.0        False
# ..         ...          ...
# 65         1.0         True
# 66         1.0         True
# 67         1.0         True
# 68        -1.0        False
# 69        -1.0        False
# 70         1.0         True
# 71        -1.0        False
# 72         1.0         True
# 73        -1.0         True
# 74        -1.0        False
# 75         1.0         True
# 76         1.0         True
# 77        -1.0         True
# 78         1.0         True
# 79         1.0         True
# 80        -1.0        False
# 81         1.0         True
# 82         1.0         True
# 83        -1.0        False
# 84        -1.0        False
# 85        -1.0        False
# 86         1.0         True
# 87         1.0         True
# 88        -1.0        False
# 89        -1.0        False
# 90         1.0         True
# 91        -1.0        False
# 92        -1.0         True
# 93        -1.0        False
# 94        -1.0        False
#
# [95 rows x 4 columns]

# %%
# cross validation of training set using SVM
from sklearn.model_selection import cross_val_score
clf_cv = svm.SVC(kernel='linear', C=1, gamma=1)
scores = cross_val_score(clf_cv, X_train_tfidf, y_trn['sentimentAnnotation'].values, cv=10)
scores
print("Cross validation accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Cross validation accuracy: 0.64 (+/- 0.15)
